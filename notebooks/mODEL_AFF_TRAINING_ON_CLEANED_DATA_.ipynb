# %%
# Importing Libraries :

# %%
import pandas as pd
import numpy as np 
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv("AFF_cleaned_Final.csv")

# %%
df
# Out:
#      Unnamed: 0  Temperature  RH  Ws  Rain  FFMC   DMC    DC  ISI   BUI  FWI  \
# 0             0           29  57  18   0.0  65.7   3.4   7.6  1.3   3.4  0.5
# 1             1           29  61  13   1.3  64.4   4.1   7.6  1.0   3.9  0.4
# 2             2           26  82  22  13.1  47.1   2.5   7.1  0.3   2.7  0.1
# 3             3           25  89  13   2.5  28.6   1.3   6.9  0.0   1.7  0.0
# 4             4           27  77  16   0.0  64.8   3.0  14.2  1.2   3.9  0.5
# ..          ...          ...  ..  ..   ...   ...   ...   ...  ...   ...  ...
# 238         238           30  65  14   0.0  85.4  16.0  44.5  4.5  16.9  6.5
# 239         239           28  87  15   4.4  41.1   6.5   8.0  0.1   6.2  0.0
# 240         240           27  87  29   0.5  45.9   3.5   7.9  0.4   3.4  0.2
# 241         241           24  54  18   0.1  79.7   4.3  15.2  1.7   5.1  0.7
# 242         242           24  64  15   0.2  67.3   3.8  16.5  1.2   4.8  0.5
#
#           Classes  Region
# ...

# %%
df.drop(columns=['Unnamed: 0'],inplace=True)

# %%
df.to_csv("AFF_cleaned_Finally_.csv")

# %%
df.head()
# Out:
#    Temperature  RH  Ws  Rain  FFMC  DMC    DC  ISI  BUI  FWI      Classes  \
# 0           29  57  18   0.0  65.7  3.4   7.6  1.3  3.4  0.5  not fire
# 1           29  61  13   1.3  64.4  4.1   7.6  1.0  3.9  0.4  not fire
# 2           26  82  22  13.1  47.1  2.5   7.1  0.3  2.7  0.1  not fire
# 3           25  89  13   2.5  28.6  1.3   6.9  0.0  1.7  0.0  not fire
# 4           27  77  16   0.0  64.8  3.0  14.2  1.2  3.9  0.5  not fire
#
#    Region
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0

# %%
df.head()
# Out:
#    Temperature  RH  Ws  Rain  FFMC  DMC    DC  ISI  BUI  FWI      Classes  \
# 0           29  57  18   0.0  65.7  3.4   7.6  1.3  3.4  0.5  not fire
# 1           29  61  13   1.3  64.4  4.1   7.6  1.0  3.9  0.4  not fire
# 2           26  82  22  13.1  47.1  2.5   7.1  0.3  2.7  0.1  not fire
# 3           25  89  13   2.5  28.6  1.3   6.9  0.0  1.7  0.0  not fire
# 4           27  77  16   0.0  64.8  3.0  14.2  1.2  3.9  0.5  not fire
#
#    Region
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0

# %%
df.isnull().sum()
# Out:
# Temperature    0
# RH             0
# Ws             0
# Rain           0
# FFMC           0
# DMC            0
# DC             0
# ISI            0
# BUI            0
# FWI            0
# Classes        0
# Region         0
# dtype: int64

# %%
df.tail()
# Out:
#      Temperature  RH  Ws  Rain  FFMC   DMC    DC  ISI   BUI  FWI  \
# 238           30  65  14   0.0  85.4  16.0  44.5  4.5  16.9  6.5
# 239           28  87  15   4.4  41.1   6.5   8.0  0.1   6.2  0.0
# 240           27  87  29   0.5  45.9   3.5   7.9  0.4   3.4  0.2
# 241           24  54  18   0.1  79.7   4.3  15.2  1.7   5.1  0.7
# 242           24  64  15   0.2  67.3   3.8  16.5  1.2   4.8  0.5
#
#           Classes  Region
# 238       fire          1
# 239   not fire          1
# 240   not fire          1
# 241   not fire          1
# 242  not fire           1

# %%
df['Classes'].unique().sum()
# Out:
# 'not fire   fire   firefire not firenot fire not fire     not fire    '

# %%
df['Classes'] =np.where(df['Classes'].str.contains('not fire'),0,1)  

# 1 : FIRE
# 0 : NOT FIRE

# %%
df['Classes'].unique()
# Out:
# array([0, 1])

# %%
df['Classes'].unique()
# Out:
# array([0, 1])

# %%
df['Classes'].unique().sum()
# Out:
# 1

# %%
df.tail()
# Out:
#      Temperature  RH  Ws  Rain  FFMC   DMC    DC  ISI   BUI  FWI  Classes  \
# 238           30  65  14   0.0  85.4  16.0  44.5  4.5  16.9  6.5        1
# 239           28  87  15   4.4  41.1   6.5   8.0  0.1   6.2  0.0        0
# 240           27  87  29   0.5  45.9   3.5   7.9  0.4   3.4  0.2        0
# 241           24  54  18   0.1  79.7   4.3  15.2  1.7   5.1  0.7        0
# 242           24  64  15   0.2  67.3   3.8  16.5  1.2   4.8  0.5        0
#
#      Region
# 238       1
# 239       1
# 240       1
# 241       1
# 242       1

# %%
df['Classes'].value_counts()
# Out:
# 1    137
# 0    106
# Name: Classes, dtype: int64

# %% [markdown]
# ## Dividing the dataset into : INDEPENDENT FEATURE AND DEPENDENT FEATURS

# %%
X = df.drop('FWI',axis=1)  # Independent features
y = df['FWI']              # dependent features( need to predict this )

# %%
X.head()
# Out:
#    Temperature  RH  Ws  Rain  FFMC  DMC    DC  ISI  BUI  Classes  Region
# 0           29  57  18   0.0  65.7  3.4   7.6  1.3  3.4        0       0
# 1           29  61  13   1.3  64.4  4.1   7.6  1.0  3.9        0       0
# 2           26  82  22  13.1  47.1  2.5   7.1  0.3  2.7        0       0
# 3           25  89  13   2.5  28.6  1.3   6.9  0.0  1.7        0       0
# 4           27  77  16   0.0  64.8  3.0  14.2  1.2  3.9        0       0

# %%
y
# Out:
# 0      0.5
# 1      0.4
# 2      0.1
# 3      0.0
# 4      0.5
#       ...
# 238    6.5
# 239    0.0
# 240    0.2
# 241    0.7
# 242    0.5
# Name: FWI, Length: 243, dtype: float64

# %% [markdown]
# # Dividing Dataset into Train , Test and split the dataset

# %%
# using sklearn

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.25,random_state=45)

# %%
X_train.shape
# Out:
# (182, 11)

# %%
X_test.shape
# Out:
# (61, 11)

# %%
y_train.shape ,y_test.shape
# Out:
# ((182,), (61,))

# %% [markdown]
# # Feature Selection based on the Correlation

# %%
X_train.corr()
# Out:
#              Temperature        RH        Ws      Rain      FFMC       DMC  \
# Temperature     1.000000 -0.660795 -0.278939 -0.370676  0.686037  0.489583
# RH             -0.660795  1.000000  0.229917  0.232069 -0.650166 -0.410087
# Ws             -0.278939  0.229917  1.000000  0.274892 -0.170338 -0.015730
# Rain           -0.370676  0.232069  0.274892  1.000000 -0.549174 -0.277992
# FFMC            0.686037 -0.650166 -0.170338 -0.549174  1.000000  0.591452
# DMC             0.489583 -0.410087 -0.015730 -0.277992  0.591452  1.000000
# DC              0.377292 -0.228161  0.080056 -0.289827  0.496276  0.881988
# ISI             0.625153 -0.705548 -0.015707 -0.339779  0.746234  0.671494
# BUI             0.461357 -0.354014  0.024178 -0.289332  0.579781  0.982540
# Classes         0.531519 -0.437177 -0.106463 -0.364482  0.768765  0.560499
# Region          0.303753 -0.427609 -0.249133 -0.087988  0.245305  0.210788
#
#                    DC       ISI       BUI   Classes    Region
# ...

# %%
## check for multicollinearity :

# %%
plt.figure(figsize=(12,10))
corr = X_train.corr()
sns.heatmap(corr,annot=True)
# Out:
# <AxesSubplot: >

# %%
corr
# Out:
#              Temperature        RH        Ws      Rain      FFMC       DMC  \
# Temperature     1.000000 -0.660795 -0.278939 -0.370676  0.686037  0.489583
# RH             -0.660795  1.000000  0.229917  0.232069 -0.650166 -0.410087
# Ws             -0.278939  0.229917  1.000000  0.274892 -0.170338 -0.015730
# Rain           -0.370676  0.232069  0.274892  1.000000 -0.549174 -0.277992
# FFMC            0.686037 -0.650166 -0.170338 -0.549174  1.000000  0.591452
# DMC             0.489583 -0.410087 -0.015730 -0.277992  0.591452  1.000000
# DC              0.377292 -0.228161  0.080056 -0.289827  0.496276  0.881988
# ISI             0.625153 -0.705548 -0.015707 -0.339779  0.746234  0.671494
# BUI             0.461357 -0.354014  0.024178 -0.289332  0.579781  0.982540
# Classes         0.531519 -0.437177 -0.106463 -0.364482  0.768765  0.560499
# Region          0.303753 -0.427609 -0.249133 -0.087988  0.245305  0.210788
#
#                    DC       ISI       BUI   Classes    Region
# ...

# %% [markdown]
# # Here corr is matrix :
# we have to check each and every row and columns and if it is bigger than some value(govern by domain expertise) , our aim is to find highly correlated independent features . need to remove this
# from the model( multicollinearity)

# %%
def correlation(dataset,threshold):
    col_corr = set()
    corr_matrix=dataset.corr()
    for i in range (len(corr_matrix.columns)):
        for j in range(i):
            if abs(corr_matrix.iloc[i,j])>threshold:
                colname = corr_matrix.columns[i]
                col_corr.add(colname)
    return col_corr

# %%
# Threshold Domain Expertise  : 0.85 (given by them)
corr_features = correlation(X_train,0.85)
corr_features
# Out:
# {'BUI', 'DC'}

# %%
# Here two independent features are higly correlated : BUI and DC

# %%
## drop features when correlation is more than 0.85 
X_train.drop(corr_features,axis=1,inplace=True)
X_test.drop(corr_features,axis=1,inplace=True)
X_train.shape,X_test.shape
# Out:
# ((182, 9), (61, 9))

# %%
# Now we have less number of columns or features to predict target value _

# %% [markdown]
# ## Feature Scaling & Standardization :

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()

# %%
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled =scaler.transform(X_test)

# %%
X_train
# Out:
#      Temperature  RH  Ws  Rain  FFMC   DMC  ISI  Classes  Region
# 147           36  62  16   0.0  87.8  16.5  7.0        1       1
# 119           32  47  14   0.7  77.5   7.1  1.8        0       0
# 112           31  55  11   0.0  87.8  16.5  5.4        1       0
# 74            33  66  14   0.0  87.0  21.7  5.7        1       0
# 21            31  67  17   0.1  79.1   7.0  2.4        0       0
# ..           ...  ..  ..   ...   ...   ...  ...      ...     ...
# 32            32  76  20   0.7  63.1   2.6  1.3        0       0
# 124           29  80  14   2.0  48.7   2.2  0.3        0       1
# 131           30  41  15   0.0  89.4  13.3  8.4        1       1
# 158           38  43  13   0.5  85.0  13.0  4.1        1       1
# 203           37  53  14   0.0  89.5  41.1  8.0        1       1
#
# [182 rows x 9 columns]

# %%
X_train_scaled
# Out:
# array([[ 1.03973391,  0.00396204,  0.21039187, ...,  0.54677005,
#          0.85634884,  1.01105006],
#        [-0.03239964, -0.97934302, -0.52597966, ..., -0.71718494,
#         -1.16774842, -0.98907071],
#        [-0.30043303, -0.45491366, -1.63053696, ...,  0.15786082,
#          0.85634884, -0.98907071],
#        ...,
#        [-0.56846642, -1.37266504, -0.1577939 , ...,  0.88706562,
#          0.85634884,  1.01105006],
#        [ 1.57580069, -1.2415577 , -0.89416543, ..., -0.15812793,
#          0.85634884,  1.01105006],
#        [ 1.3077673 , -0.586021  , -0.52597966, ...,  0.78983831,
#          0.85634884,  1.01105006]])

# %%
X_test_scaled
# Out:
# array([[ 5.03667137e-01, -1.30711137e+00,  5.78577631e-01,
#         -3.18484456e-01,  7.14407284e-01,  6.56863671e-01,
#          3.46358924e+00,  8.56348839e-01,  1.01105006e+00],
#        [-3.00433029e-01, -5.20467329e-01, -1.63053696e+00,
#         -3.66191593e-01,  2.83576068e-01, -7.00598078e-01,
#         -5.47037153e-01, -1.16774842e+00, -9.89070710e-01],
#        [-3.00433029e-01,  3.97284058e-01, -5.25979664e-01,
#         -3.66191593e-01,  5.16088153e-01, -2.30114176e-01,
#         -3.65937939e-02,  8.56348839e-01, -9.89070710e-01],
#        [ 7.71700526e-01, -1.92698976e-01,  5.78577631e-01,
#         -3.66191593e-01,  6.52859967e-01, -2.18672035e-02,
#          5.22463219e-01,  8.56348839e-01, -9.89070710e-01],
#        [ 1.30776730e+00, -1.70043340e+00, -8.94165429e-01,
#         -7.99487729e-02,  5.70796879e-01,  2.17231173e-01,
#          1.20198593e-02,  8.56348839e-01,  1.01105006e+00],
#        [ 7.71700526e-01, -7.17128340e-01, -8.94165429e-01,
# ...

# %%
plt.subplots(figsize=(15,10))
plt.subplot(1,2,1)            
sns.boxplot(data=X_train)
plt.title(label="Before Scaling")            
plt.subplot(1,2,2)
sns.boxplot(data=X_train_scaled)
plt.title(label="After Scaling")
# Out:
# /tmp/ipykernel_84/3992205575.py:2: MatplotlibDeprecationWarning: Auto-removal of overlapping axes is deprecated since 3.6 and will be removed two minor releases later; explicitly call ax.remove() as needed.
#   plt.subplot(1,2,1)
# Text(0.5, 1.0, 'After Scaling')

# %%
plt.subplots(figsize=(15, 5))
plt.subplot(1, 2, 1)
sns.boxplot(data=X_train)
plt.title('X_train Before Scaling')
plt.subplot(1, 2, 2)
sns.boxplot(data=X_train_scaled)
plt.title('X_train After Scaling')
# Out:
# /tmp/ipykernel_84/160744393.py:2: MatplotlibDeprecationWarning: Auto-removal of overlapping axes is deprecated since 3.6 and will be removed two minor releases later; explicitly call ax.remove() as needed.
#   plt.subplot(1, 2, 1)
# Text(0.5, 1.0, 'X_train After Scaling')

# %% [markdown]
# ## Model Training : Ridge , Lasso and Elastic Net Regression :

# %% [markdown]
# ### Linear Regression Model

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import r2_score

# %%
linreg = LinearRegression()
linreg.fit(X_train_scaled,y_train)
y_pred = linreg.predict(X_test_scaled)
mae = mean_absolute_error(y_test,y_pred)
score=r2_score(y_test , y_pred)
print("Mean absolute error",mae)
print("R2 Score",score)
# Out:
# Mean absolute error 0.7713645614904525
# R2 Score 0.9096193210066799

# %% [markdown]
# ### Ridge Regression :

# %%
from sklearn.linear_model import Ridge
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import r2_score
ridge=Ridge()
ridge.fit(X_train_scaled,y_train)
y_pred=ridge.predict(X_test_scaled)
mae=mean_absolute_error(y_test,y_pred)
score=r2_score(y_test,y_pred)
print("Mean absolute error", mae)
print("R2 Score", score)
# Out:
# Mean absolute error 0.7619995110582053
# R2 Score 0.9123601798432848

# %% [markdown]
# ### Lasso Regression

# %%
from sklearn.linear_model import ElasticNet
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import r2_score
elastic=ElasticNet()
elastic.fit(X_train_scaled,y_train)
y_pred=elastic.predict(X_test_scaled)
mae=mean_absolute_error(y_test,y_pred)
score=r2_score(y_test,y_pred)
print("Mean absolute error", mae)
print("R2 Score", score)
# Out:
# Mean absolute error 1.715773792920221
# R2 Score 0.8844387249095774

# %%
import pickle
pickle.dump(scaler,open('scaler.pkl','wb'))
pickle.dump(ridge,open('ridge.pkl','wb'))

# %%
## we pickled two files ,Since both linear and ridge have almost same r2 score , ridge is chosen because it reduces overfitting while linear regression may increase overfitting .

# %%
# now get ready to make an web app
